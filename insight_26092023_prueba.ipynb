# %% [markdown]
# <a href="https://colab.research.google.com/github/adcaceres69/Proyecto-DENGUE/blob/main/insight_26092023_prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ESTE EJEMPLO NO LO LLEGUE A USAR!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_features = pd.read_csv('/dengue_features_train.csv')
df_label = pd.read_csv('/dengue_labels_train.csv')

# %%
#para evitar notaciones cientificas; formateo la salidas de los campos numericos
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
df_features.describe()
# Out:
#          year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# count 1456.00     1456.00  1262.00  1404.00  1434.00  1434.00
# mean  2001.03       26.50     0.14     0.13     0.20     0.20
# std      5.41       15.02     0.14     0.12     0.07     0.08
# min   1990.00        1.00    -0.41    -0.46    -0.02    -0.06
# 25%   1997.00       13.75     0.04     0.05     0.16     0.14
# 50%   2002.00       26.50     0.13     0.12     0.20     0.19
# 75%   2005.00       39.25     0.25     0.22     0.25     0.25
# max   2010.00       53.00     0.51     0.45     0.54     0.55
#
#        precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# count               1443.00                1446.00                1446.00
# mean                  45.76                 298.70                 299.23
# std                   43.72                   1.36                   1.26
# min                    0.00                 294.64                 294.89
# ...

# %%
df_features['city'].value_counts()
# Out:
# sj    936
# iq    520
# Name: city, dtype: int64

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         1456 non-null   object
#  1   year         1456 non-null   int64
#  2   weekofyear   1456 non-null   int64
#  3   total_cases  1456 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 45.6+ KB

# %%
df_label.describe()
# Out:
#          year  weekofyear  total_cases
# count 1456.00     1456.00      1456.00
# mean  2001.03       26.50        24.68
# std      5.41       15.02        43.60
# min   1990.00        1.00         0.00
# 25%   1997.00       13.75         5.00
# 50%   2002.00       26.50        12.00
# 75%   2005.00       39.25        28.00
# max   2010.00       53.00       461.00

# %%
df_label['city'].value_counts()
# Out:
# sj    936
# iq    520
# Name: city, dtype: int64

# %%
# visualizacion
# histograma
df_label['total_cases'].hist(bins=30)
plt.show()

# %%
# boxplot
sns.boxplot(data=df_label, x='city', y='total_cases')
plt.show()

# %%
# dispersion
sns.scatterplot(data=df_features, x='ndvi_ne', y='total_cases') # df_ features, mo tiene el campo total_cases
plt.show()

# %%
df_features
# Out:
#      city  year  weekofyear week_start_date  ndvi_ne  ndvi_nw  ndvi_se  \
# 0      sj  1990          18      1990-04-30     0.12     0.10     0.20
# 1      sj  1990          19      1990-05-07     0.17     0.14     0.16
# 2      sj  1990          20      1990-05-14     0.03     0.17     0.16
# 3      sj  1990          21      1990-05-21     0.13     0.25     0.23
# 4      sj  1990          22      1990-05-28     0.20     0.26     0.25
# ...   ...   ...         ...             ...      ...      ...      ...
# 1451   iq  2010          21      2010-05-28     0.34     0.32     0.26
# 1452   iq  2010          22      2010-06-04     0.16     0.16     0.14
# 1453   iq  2010          23      2010-06-11     0.25     0.15     0.25
# 1454   iq  2010          24      2010-06-18     0.33     0.25     0.28
# 1455   iq  2010          25      2010-06-25     0.30     0.23     0.27
#
#       ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# ...

# %%
(df_features.iloc[:,4:].corr())
# Out:
#                                        ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# ndvi_ne                                   1.00     0.85     0.61     0.67
# ndvi_nw                                   0.85     1.00     0.56     0.65
# ndvi_se                                   0.61     0.56     1.00     0.82
# ndvi_sw                                   0.67     0.65     0.82     1.00
# precipitation_amt_mm                      0.21     0.19     0.07     0.12
# reanalysis_air_temp_k                    -0.34    -0.32    -0.16    -0.23
# reanalysis_avg_temp_k                    -0.04    -0.03     0.05     0.02
# reanalysis_dew_point_temp_k               0.06     0.06     0.00     0.02
# reanalysis_max_air_temp_k                 0.63     0.61     0.47     0.55
# reanalysis_min_air_temp_k                -0.62    -0.59    -0.41    -0.49
# reanalysis_precip_amt_kg_per_m2           0.20     0.19     0.03     0.10
# reanalysis_relative_humidity_percent      0.46     0.45     0.22     0.31
# ...

# %%
# correlaciones
plt.figure(figsize= (13,13))
correlation_matrix = (df_features.iloc[:,4:].corr())
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1262 non-null   float64
#  5   ndvi_nw                                1404 non-null   float64
#  6   ndvi_se                                1434 non-null   float64
#  7   ndvi_sw                                1434 non-null   float64
#  8   precipitation_amt_mm                   1443 non-null   float64
#  9   reanalysis_air_temp_k                  1446 non-null   float64
# ...

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         1456 non-null   object
#  1   year         1456 non-null   int64
#  2   weekofyear   1456 non-null   int64
#  3   total_cases  1456 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 45.6+ KB

# %%
df_features['total_cases'] = df_label['total_cases']

# %% [markdown]
# ## VISUALIZACIONES

# %%
#histogramas
df_features['total_cases'].hist()
plt.title('Distribución de Total Cases')
plt.xlabel('Total Cases')
plt.ylabel('Frecuencia')
plt.show()

# %%
# boxplot total de casos
plt.figure(figsize= (10,8))
df_features.boxplot(column=['total_cases'])
plt.title('Boxplot de Total Cases')
plt.show()

# %%
#dispersión total cases
df_features.plot(kind='scatter', x='reanalysis_air_temp_k', y='total_cases')
plt.title('Total Cases vs Reanalysis Air Temp')
plt.show()

# %%
# antes de seguir --- trato los nulos
df_features.fillna(df_features.mean(), inplace=True)
# Out:
# <ipython-input-52-c7b202a6871e>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_features.fillna(df_features.mean(), inplace=True)

# %%
#correlaciones
plt.figure(figsize= (13,13))
corr = (df_features.iloc[:,4:].corr())
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Heatmap de Correlación')
plt.show()

# correlaciones
#plt.figure(figsize= (13,13))
#correlation_matrix = (df_features.iloc[:,4:].corr())
#sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#plt.show()

# %%
# evaluando la correlación
correlation = (df_features.iloc[:,4:].corr())
print(correlation['total_cases'].sort_values(ascending=False))
# Out:
# total_cases                              1.00
# reanalysis_min_air_temp_k                0.32
# station_min_temp_c                       0.27
# reanalysis_air_temp_k                    0.26
# reanalysis_avg_temp_k                    0.15
# reanalysis_dew_point_temp_k              0.14
# reanalysis_specific_humidity_g_per_kg    0.13
# station_avg_temp_c                       0.12
# reanalysis_precip_amt_kg_per_m2         -0.01
# reanalysis_sat_precip_amt_mm            -0.04
# precipitation_amt_mm                    -0.04
# station_max_temp_c                      -0.04
# station_precip_mm                       -0.07
# ndvi_se                                 -0.12
# reanalysis_relative_humidity_percent    -0.13
# ndvi_sw                                 -0.14
# ndvi_nw                                 -0.14
# ndvi_ne                                 -0.16
# reanalysis_max_air_temp_k               -0.19
# station_diur_temp_rng_c                 -0.24
# ...

# %%
# lineas
df_features['total_cases'].plot()
plt.title('Tendencia de Total Cases a lo largo del tiempo')
plt.xlabel('Tiempo')
plt.ylabel('Total Cases')
plt.show()

# %%
# barras
df_features.groupby('year')['total_cases'].sum().plot(kind='bar')
plt.title('Total Cases por Año')
plt.ylabel('Total Cases')
plt.show()

# %%
# barras
df_features.groupby('city')['total_cases'].sum().plot(kind='bar')
plt.title('Total Cases por Ciudad')
plt.ylabel('Total Cases')
plt.show()

# %%
# dispersion de una variables
sns.scatterplot(data=df_features, x='ndvi_ne', y='total_cases') #
plt.show()

# %%
df_features.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'total_cases'],
#       dtype='object')

# %%
#Crear un Pairplot del dataset
plt.figure(dpi=120)
sns.pairplot(df_features)
plt.show()

# %%
col_ndvi =['ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw']

# %%
#Crear un Pairplot del dataset
plt.figure(dpi=120)
sns.pairplot(df_features[col_ndvi].corr())
plt.show()

# %%
# casos en el tiempo
sns.lineplot(data=df_features, x='weekofyear', y='total_cases', hue='year')
plt.show()

# %% [markdown]
# ¡Por supuesto! Para buscar insights en los datos, el Análisis Exploratorio de Datos (EDA) es el enfoque ideal. Aquí te detallo algunos pasos y técnicas que podrías utilizar:
#
# ### 1. **Estadísticas Descriptivas:**
#    - Usa `df.describe()` para obtener un resumen estadístico de las variables numéricas.
#    - Usa `df['columna'].value_counts()` para contar la frecuencia de las variables categóricas.
#
# ```python
# print(df.describe())
# ```
#
# ### 2. **Visualización de Datos:**
#    - Utiliza histogramas y boxplots para visualizar la distribución de las variables numéricas.
#    - Utiliza gráficos de barras para visualizar la distribución de las variables categóricas.
#    - Utiliza gráficos de dispersión para visualizar las relaciones entre dos variables numéricas.
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Histograma
# df['total_cases'].hist(bins=30)
# plt.show()
#
# # Boxplot
# sns.boxplot(data=df, x='city', y='total_cases')
# plt.show()
#
# # Gráfico de dispersión
# sns.scatterplot(data=df, x='ndvi_ne', y='total_cases')
# plt.show()
# ```
#
# ### 3. **Correlación:**
#    - Calcula la correlación entre las variables numéricas para identificar las relaciones lineales entre ellas.
#
# ```python
# correlation_matrix = df.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.show()
# ```
#
# ### 4. **Análisis de la Variable Objetivo:**
#    - Analiza la variable objetivo ("total_cases") para entender su distribución y relación con otras variables.
#
# ### 5. **Análisis de Valores Nulos:**
#    - Analiza las columnas con valores nulos para decidir cómo manejarlos.
#
# ```python
# sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# plt.show()
# ```
#
# ### 6. **Análisis Temporal:**
#    - Si tienes variables temporales como "year" y "weekofyear", analiza las tendencias y la estacionalidad.
#
# ```python
# sns.lineplot(data=df, x='weekofyear', y='total_cases', hue='year')
# plt.show()
# ```
#
# Recuerda que este es un enfoque general, y puedes y deberías personalizarlo para ajustarlo a tus necesidades y preguntas específicas. Además, cada visualización o estadística debe ser seguida de interpretaciones y conclusiones que puedas sacar de ellas.
#
# ¿Te gustaría que te ayude con algún paso en particular o tienes alguna otra pregunta o requerimiento?
